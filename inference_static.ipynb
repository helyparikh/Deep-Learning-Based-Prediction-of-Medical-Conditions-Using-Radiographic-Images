# %%
import os
import random
import matplotlib.pyplot as plt
import cv2
import pandas as pd
import numpy as np
import imutils
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-cb3632f8321e> in <module>
#       2 import random
#       3 import matplotlib.pyplot as plt
# ----> 4 import cv2
#       5 import pandas as pd
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'cv2'

# %%
from keras.models import load_model
 
# load model
model = load_model('resnet_backup.h5')
# Out:
# Using TensorFlow backend.

# %%
columns = ['Atelectasis', 'Cardiomegaly', 'Consolidation', 'Edema', 'Enlarged', 'Fracture', 'Lung Lesion',
           'Lung Opacity', 'No Finding', 'Pleural Effusion', 'Pleural Other', 'Pneumonia', 'Pneumothorax',
          'Support Devices']

# %% [markdown]
# ## Please provide image path here to get prediction result

# %%
imagepath= 'output_5_0.png'

# %%
image = cv2.imread(imagepath)
plt.imshow(image)
image = cv2.resize(image, (224,224))
image = image / 255
prediction = model.predict(np.asarray([image]))

# %%
for i in range(len(prediction[0])):
    print(columns[i] +": "+str(prediction[0][i]))
# Out:
# Atelectasis: 2.0698923e-16
# Cardiomegaly: 7.6726203e-16
# Consolidation: 7.13025e-18
# Edema: 2.374437e-17
# Enlarged: 3.0121223e-17
# Fracture: 2.2814015e-17
# Lung Lesion: 2.3131407e-18
# Lung Opacity: 5.3380526e-17
# No Finding: 9.50943e-17
# Pleural Effusion: 1.9168001e-16
# Pleural Other: 1.0984683e-17
# Pneumonia: 1.0
# Pneumothorax: 2.5453979e-17
# Support Devices: 2.389703e-17
